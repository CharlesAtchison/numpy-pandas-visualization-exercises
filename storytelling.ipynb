# %%
from wand.image import Image as WImage

# %%
WImage(filename='storytelling.pdf[0]')
# Out:
# <wand.image.Image: 73d7de6 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[1]')
# Out:
# <wand.image.Image: 9091a6e 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[2]')
# Out:
# <wand.image.Image: 8f90332 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[3]')
# Out:
# <wand.image.Image: b1a6e3e 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[4]')
# Out:
# <wand.image.Image: 20f9f42 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[5]')
# Out:
# <wand.image.Image: 8032fc4 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[6]')
# Out:
# <wand.image.Image: 88e5107 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[7]')
# Out:
# <wand.image.Image: 90f0818 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[8]')
# Out:
# <wand.image.Image: e23a4ed 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[9]')
# Out:
# <wand.image.Image: dbc68bd 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[10]')
# Out:
# <wand.image.Image: 2a499c0 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[11]')
# Out:
# <wand.image.Image: b367a7d 'PDF' (720x405)>

# %%
WImage(filename='storytelling.pdf[12]')
# Out:
# <wand.image.Image: cb1e2d3 'PDF' (720x405)>
